# %%
import pandas as pd

# %%
carData=pd.read_csv("car-sales-missing-data.csv")

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# NaN=Not A Number . represent missing data

# %% [markdown]
# To deal with missing value

# %% [markdown]
# all NaN values are dropped but temporary

# %%
carData.dropna() # temporary
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carData.dropna(inplace=True) # permanent change

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
carData=pd.read_csv("car-sales-missing-data.csv")

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carData=carData.dropna()

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
carData=pd.read_csv("car-sales-missing-data.csv")

# %% [markdown]
# count Null values

# %%
carData.isna()
# Out:
#     Make  Colour  Odometer  Doors  Price
# 0  False   False     False  False  False
# 1  False   False     False  False  False
# 2  False   False      True  False  False
# 3  False   False     False  False  False
# 4  False   False     False  False  False
# 5  False   False      True  False  False
# 6  False    True      True  False  False
# 7  False   False      True  False   True
# 8  False   False     False   True   True
# 9   True   False     False  False  False

# %%
carData.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
carData['Odometer'].isna().sum()
# Out:
# 4

# %% [markdown]
# fill null value

# %%
carData
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
carData['Colour'].fillna('Orange',inplace=True)

# %%
carData['Make'].fillna('Honda',inplace=True)

# %%
carData
# Out:
#      Make  Colour  Odometer  Doors    Price
# 0  Toyota   White  150043.0    4.0   $4,000
# 1   Honda     Red   87899.0    4.0   $5,000
# 2  Toyota    Blue       NaN    3.0   $7,000
# 3     BMW   Black   11179.0    5.0  $22,000
# 4  Nissan   White  213095.0    4.0   $3,500
# 5  Toyota   Green       NaN    4.0   $4,500
# 6   Honda  Orange       NaN    4.0   $7,500
# 7   Honda    Blue       NaN    4.0      NaN
# 8  Toyota   White   60000.0    NaN      NaN
# 9   Honda   White   31600.0    4.0   $9,700

# %% [markdown]
# mean of odometer

# %%
carData['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
carData['Odometer'].fillna(carData['Odometer'].mean(),inplace=True)

# %%
carData.fillna({'Odometer':carData['Odometer'].mean()},inplace=True)
carData
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota   White  150043.000000    4.0   $4,000
# 1   Honda     Red   87899.000000    4.0   $5,000
# 2  Toyota    Blue   92302.666667    3.0   $7,000
# 3     BMW   Black   11179.000000    5.0  $22,000
# 4  Nissan   White  213095.000000    4.0   $3,500
# 5  Toyota   Green   92302.666667    4.0   $4,500
# 6   Honda  Orange   92302.666667    4.0   $7,500
# 7   Honda    Blue   92302.666667    4.0      NaN
# 8  Toyota   White   60000.000000    NaN      NaN
# 9   Honda   White   31600.000000    4.0   $9,700

# %%
carData['Odometer']=carData['Odometer'].fillna(carData['Odometer'].mean())

# %%
carData
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota   White  150043.000000    4.0   $4,000
# 1   Honda     Red   87899.000000    4.0   $5,000
# 2  Toyota    Blue   92302.666667    3.0   $7,000
# 3     BMW   Black   11179.000000    5.0  $22,000
# 4  Nissan   White  213095.000000    4.0   $3,500
# 5  Toyota   Green   92302.666667    4.0   $4,500
# 6   Honda  Orange   92302.666667    4.0   $7,500
# 7   Honda    Blue   92302.666667    4.0      NaN
# 8  Toyota   White   60000.000000    NaN      NaN
# 9   Honda   White   31600.000000    4.0   $9,700

# %%
carData['Doors'].fillna(4,inplace=True)

# %%
carData
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota   White  150043.000000    4.0   $4,000
# 1   Honda     Red   87899.000000    4.0   $5,000
# 2  Toyota    Blue   92302.666667    3.0   $7,000
# 3     BMW   Black   11179.000000    5.0  $22,000
# 4  Nissan   White  213095.000000    4.0   $3,500
# 5  Toyota   Green   92302.666667    4.0   $4,500
# 6   Honda  Orange   92302.666667    4.0   $7,500
# 7   Honda    Blue   92302.666667    4.0      NaN
# 8  Toyota   White   60000.000000    4.0      NaN
# 9   Honda   White   31600.000000    4.0   $9,700

# %%
carData
# Out:
#      Make  Colour       Odometer  Doors    Price
# 0  Toyota   White  150043.000000    4.0   $4,000
# 1   Honda     Red   87899.000000    4.0   $5,000
# 2  Toyota    Blue   92302.666667    3.0   $7,000
# 3     BMW   Black   11179.000000    5.0  $22,000
# 4  Nissan   White  213095.000000    4.0   $3,500
# 5  Toyota   Green   92302.666667    4.0   $4,500
# 6   Honda  Orange   92302.666667    4.0   $7,500
# 7   Honda    Blue   92302.666667    4.0      NaN
# 8  Toyota   White   60000.000000    4.0      NaN
# 9   Honda   White   31600.000000    4.0   $9,700

# %%
carData1=pd.read_csv("car-sales-missing-data.csv")

# %%
carData1
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
#Lets try to convert  price into proper format

# %%
#use split or either use replace for this
#Example
for i in carData1['Price']:
    if(type(i)!=float):
        i,j=i[1:].split(",")
        print(i+j)
# Out:
# 4000
# 5000
# 7000
# 22000
# 3500
# 4500
# 7500
# 9700

# %%
newPrice = [int(data.replace("$", "").replace("," , "")) if type(data)!= float else None for data in carData1['Price']]

# %%
carData1['Price']=newPrice # since there were missing value and pandas convert whole price in float .int64 cannot store NaN

# %%
carData1
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   4000.0
# 1   Honda    Red   87899.0    4.0   5000.0
# 2  Toyota   Blue       NaN    3.0   7000.0
# 3     BMW  Black   11179.0    5.0  22000.0
# 4  Nissan  White  213095.0    4.0   3500.0
# 5  Toyota  Green       NaN    4.0   4500.0
# 6   Honda    NaN       NaN    4.0   7500.0
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   9700.0
