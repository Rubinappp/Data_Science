# %% [markdown]
# csv =comma seperated values is a text file that use comma to  seperate values
# delimited by commas

# %%
import pandas as pd

# %%
df=pd.read_csv("archive/Covid Data.csv")

# %%
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head() # top 5 rows of the dataset .by default 5 rows
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
df.tail() # last 5 rows of our data
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 1048570          2   40        97         2  ...       2        2
# 1048571          2   51        97         2  ...       2        2
# 1048572          2   55        97         2  ...       2        2
# 1048573          2   28        97         2  ...       2        2
# 1048574          2   52        97         2  ...       2        2
#
#          HIPERTENSION  OTHER_DISEASE  CARDIOVASCULAR  OBESITY  RENAL_CHRONIC  \
# ...

# %%
df.head(10) #default values n=5 can be changed
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99       97          2
# 7      2             1    1             1  9999-99-99       97          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# ...

# %% [markdown]
# shift +tab to hover

# %%
df.shape # gives dimension rows and colums
# Out:
# (1048575, 21)

# %%
df.info() # column name as well as its info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   USMER                 1048575 non-null  int64
#  1   MEDICAL_UNIT          1048575 non-null  int64
#  2   SEX                   1048575 non-null  int64
#  3   PATIENT_TYPE          1048575 non-null  int64
#  4   DATE_DIED             1048575 non-null  object
#  5   INTUBED               1048575 non-null  int64
#  6   PNEUMONIA             1048575 non-null  int64
#  7   AGE                   1048575 non-null  int64
#  8   PREGNANT              1048575 non-null  int64
#  9   DIABETES              1048575 non-null  int64
#  10  COPD                  1048575 non-null  int64
#  11  ASTHMA                1048575 non-null  int64
#  12  INMSUPR               1048575 non-null  int64
#  13  HIPERTENSION          1048575 non-null  int64
# ...

# %% [markdown]
# in pandas string are called object

# %%
df.columns # gives column names only
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
df['PNEUMONIA'].head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    2
# Name: PNEUMONIA, dtype: int64

# %%
df['PNEUMONIA'].value_counts()
# Out:
# PNEUMONIA
# 2     892534
# 1     140038
# 99     16003
# Name: count, dtype: int64

# %%
df['DIABETES'].value_counts()
# Out:
# DIABETES
# 2     920248
# 1     124989
# 98      3338
# Name: count, dtype: int64

# %%
df['DIABETES'].nunique()
# Out:
# 3

# %%
df.columns
# Out:
# Index(['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'DATE_DIED', 'INTUBED',
#        'PNEUMONIA', 'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
#        'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
#        'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU'],
#       dtype='object')

# %%
for col_name in df.columns:
    print(col_name)
# Out:
# USMER
# MEDICAL_UNIT
# SEX
# PATIENT_TYPE
# DATE_DIED
# INTUBED
# PNEUMONIA
# AGE
# PREGNANT
# DIABETES
# COPD
# ASTHMA
# INMSUPR
# HIPERTENSION
# OTHER_DISEASE
# CARDIOVASCULAR
# OBESITY
# RENAL_CHRONIC
# TOBACCO
# CLASIFFICATION_FINAL
# ICU

# %%
for col_name in df.columns:
    print(f"{col_name}:{df[col_name].nunique()}")
# Out:
# USMER:2
# MEDICAL_UNIT:13
# SEX:2
# PATIENT_TYPE:2
# DATE_DIED:401
# INTUBED:4
# PNEUMONIA:3
# AGE:121
# PREGNANT:4
# DIABETES:3
# COPD:3
# ASTHMA:3
# INMSUPR:3
# HIPERTENSION:3
# OTHER_DISEASE:3
# CARDIOVASCULAR:3
# OBESITY:3
# RENAL_CHRONIC:3
# TOBACCO:3
# CLASIFFICATION_FINAL:7
# ICU:4

# %%
for col_name in df.columns:
    print(f"{df[col_name].value_counts()}")
# Out:
# USMER
# 2    662903
# 1    385672
# Name: count, dtype: int64
# MEDICAL_UNIT
# 12    602995
# 4     314405
# 6      40584
# 9      38116
# 3      19175
# 8      10399
# 10      7873
# 5       7244
# 11      5577
# 13       996
# 7        891
# 2        169
# 1        151
# Name: count, dtype: int64
# SEX
# 1    525064
# 2    523511
# Name: count, dtype: int64
# PATIENT_TYPE
# 1    848544
# 2    200031
# Name: count, dtype: int64
# DATE_DIED
# 9999-99-99    971633
# 06/07/2020      1000
# 07/07/2020       996
# 13/07/2020       990
# 16/06/2020       979
#                ...
# 24/11/2020         1
# 17/12/2020         1
# 08/12/2020         1
# 16/03/2021         1
# 22/04/2021         1
# Name: count, Length: 401, dtype: int64
# INTUBED
# 97    848544
# 2     159050
# 1      33656
# 99      7325
# Name: count, dtype: int64
# PNEUMONIA
# 2     892534
# 1     140038
# 99     16003
# Name: count, dtype: int64
# AGE
# 30     27010
# 31     25927
# 28     25313
# 29     25134
# ...
