# %% [markdown]
# # Introduction to Matplotlib
#
# Data visualization is very important to explore data and report insights.
#
# Matplotlib is library for creating visualizations in python
# advantage= gives control over the properties of our plot

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.patches import Circle
from matplotlib.patheffects import withStroke
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

royal_blue = [0, 20/256, 82/256]


# make the figure

np.random.seed(19680801)

X = np.linspace(0.5, 3.5, 100)
Y1 = 3+np.cos(X)
Y2 = 1+np.cos(1+X/0.75)/2
Y3 = np.random.uniform(Y1, Y2, len(X))

fig = plt.figure(figsize=(7.5, 7.5))
ax = fig.add_axes([0.2, 0.17, 0.68, 0.7], aspect=1)

ax.xaxis.set_major_locator(MultipleLocator(1.000))
ax.xaxis.set_minor_locator(AutoMinorLocator(4))
ax.yaxis.set_major_locator(MultipleLocator(1.000))
ax.yaxis.set_minor_locator(AutoMinorLocator(4))
ax.xaxis.set_minor_formatter("{x:.2f}")

ax.set_xlim(0, 4)
ax.set_ylim(0, 4)

ax.tick_params(which='major', width=1.0, length=10, labelsize=14)
ax.tick_params(which='minor', width=1.0, length=5, labelsize=10,
               labelcolor='0.25')

ax.grid(linestyle="--", linewidth=0.5, color='.25', zorder=-10)

ax.plot(X, Y1, c='C0', lw=2.5, label="Blue signal", zorder=10)
ax.plot(X, Y2, c='C1', lw=2.5, label="Orange signal")
ax.plot(X[::3], Y3[::3], linewidth=0, markersize=9,
        marker='s', markerfacecolor='none', markeredgecolor='C4',
        markeredgewidth=2.5)

ax.set_title("Anatomy of a figure", fontsize=20, verticalalignment='bottom')
ax.set_xlabel("x Axis label", fontsize=14)
ax.set_ylabel("y Axis label", fontsize=14)
ax.legend(loc="upper right", fontsize=14)


# Annotate the figure

def annotate(x, y, text, code):
    # Circle marker
    c = Circle((x, y), radius=0.15, clip_on=False, zorder=10, linewidth=2.5,
               edgecolor=royal_blue + [0.6], facecolor='none',
               path_effects=[withStroke(linewidth=7, foreground='white')])
    ax.add_artist(c)

    # use path_effects as a background for the texts
    # draw the path_effects and the colored text separately so that the
    # path_effects cannot clip other texts
    for path_effects in [[withStroke(linewidth=7, foreground='white')], []]:
        color = 'white' if path_effects else royal_blue
        ax.text(x, y-0.2, text, zorder=100,
                ha='center', va='top', weight='bold', color=color,
                style='italic', fontfamily='monospace',
                path_effects=path_effects)

        color = 'white' if path_effects else 'black'
        ax.text(x, y-0.33, code, zorder=100,
                ha='center', va='top', weight='normal', color=color,
                fontfamily='monospace', fontsize='medium',
                path_effects=path_effects)


annotate(3.5, -0.13, "Minor tick label", "ax.xaxis.set_minor_formatter")
annotate(-0.03, 1.0, "Major tick", "ax.yaxis.set_major_locator")
annotate(0.00, 3.75, "Minor tick", "ax.yaxis.set_minor_locator")
annotate(-0.15, 3.00, "Major tick label", "ax.yaxis.set_major_formatter")
annotate(1.68, -0.39, "xlabel", "ax.set_xlabel")
annotate(-0.38, 1.67, "ylabel", "ax.set_ylabel")
annotate(1.52, 4.15, "Title", "ax.set_title")
annotate(1.75, 2.80, "Line", "ax.plot")
annotate(2.25, 1.54, "Markers", "ax.scatter")
annotate(3.00, 3.00, "Grid", "ax.grid")
annotate(3.60, 3.58, "Legend", "ax.legend")
annotate(2.5, 0.55, "Axes", "fig.subplots")
annotate(4, 4.5, "Figure", "plt.figure")
annotate(0.65, 0.01, "x Axis", "ax.xaxis")
annotate(0, 0.36, "y Axis", "ax.yaxis")
annotate(4.0, 0.7, "Spine", "ax.spines")

# frame around figure
fig.patch.set(linewidth=4, edgecolor='0.5')
plt.show()

# %% [markdown]
# ***

# %%
import matplotlib.pyplot as plt # subpackage pyplot

# %%
temperature_celsius = [15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45]
ice_cream_sales_npr = [200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800]

# %% [markdown]
# #### Scatter Plot

# %%
plt.scatter(x=temperature_celsius,y=ice_cream_sales_npr)

# %% [markdown]
# To add title and label

# %%
plt.scatter(x=temperature_celsius,y=ice_cream_sales_npr,marker="o",c="red")
# Some common marker shapes are, +, *, o, ^, d, v, s.
# color: we can give any color
plt.title("Temperature vs Ice cream Sales")
plt.xlabel("Temperature")
plt.ylabel("Ice cream Sales")

plt.grid(True)
plt.show()

# %%
years = list(range(2010, 2022))
weights = [70, 72, 71, 73, 72, 71, 70, 72, 74, 73, 80, 75]

# %%
plt.plot(years,weights)
plt.show()

# %%
plt.plot(years,weights,c="green",marker="o",linestyle="--")
plt.show()

# %% [markdown]
# #### Bar Chart

# %%
candidates = ["Balendra Shah", "Sirjana Singh", "Keshav Sthapit", "Suman Sayami", "Madan Das Shrestha", "Others"]
votes = [61767, 38341, 38117, 13770, 5770, 2141]

# %%
plt.bar(candidates,votes)
plt.show()

# %% [markdown]
# In above bar, names are overlapped so to solve this
# - we can rotate the xtick labels for better readability-------  plt.xticks(rotation=angle_value)
# - When you call plt.xticks(rotation=90), Matplotlib applies this change to the current active plot,

# %%
plt.bar(candidates,votes,color="green")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Using the data below to plot bar  of the vote counts of candidate.

# %% [markdown]
# #### ![image-2.png](attachment:image-2.png)

# %%
deputy_mayor={"Party":["CPN","Unified Socialist","Independent","RPP","Independent","Bibeksheel Sajha"],
      "Candidate":["Sunita Dangol","Rameshwor Shrestha","Bidhya Shrestha","Binita Magaiya",
                   "Benji Singh Maharjan","Kirti Kansakar"],
       "Votes" : [68612, 23806, 13695, 12141, 6555, 2590]}

# %% [markdown]
# 1.Converting into data frame

# %%
import pandas as pd

# %%
dep_df=pd.DataFrame(deputy_mayor)

# %%
dep_df
# Out:
#                Party             Candidate  Votes
# 0                CPN         Sunita Dangol  68612
# 1  Unified Socialist    Rameshwor Shrestha  23806
# 2        Independent       Bidhya Shrestha  13695
# 3                RPP        Binita Magaiya  12141
# 4        Independent  Benji Singh Maharjan   6555
# 5   Bibeksheel Sajha        Kirti Kansakar   2590

# %% [markdown]
# 2.Finding total votes for parties.

# %%
dep_df["Votes"].sum()
# Out:
# 127399

# %%
data=dep_df.groupby("Party")["Votes"].sum().reset_index()
data
# Out:
#                Party  Votes
# 0   Bibeksheel Sajha   2590
# 1                CPN  68612
# 2        Independent  20250
# 3                RPP  12141
# 4  Unified Socialist  23806

# %%
df_Votes=list(data['Votes'])
df_Party=list(data['Party'])

# %%
plt.bar(df_Party,df_Votes)
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# #### With orient="index", pandas constructs the DataFrame such that:
#
# - The keys of the outer dictionary ("CPN (UML)", "Unified Socialist", etc.) become the index (row labels) of the DataFrame.
# - The inner dictionaries' keys ("Candidate", "Votes") become the column labels.
# - The inner dictionaries' values ("Sunita Dangol", 68612, etc.) become the corresponding data in the DataFrame.

# %%
import pandas as pd
data = {
    "CPN (UML)": {"Candidate": "Sunita Dangol", "Votes": 68612},
    "Unified Socialist": {"Candidate": "Rameshwar Shrestha", "Votes": 23806},
    "Independent": {"Candidate": "Bidhya Shrestha (Maharjan)", "Votes": 13695},
    "RPP": {"Candidate": "Binita Magaiya", "Votes": 12141},
    "Independent": {"Candidate": "Benji Singh Maharjan", "Votes": 6555},
    "Bibeksheel Sajha": {"Candidate": "Kirti Kansakar", "Votes": 2590}
}

df = pd.DataFrame(data)

# %%
 # but we need party name ,candidate and votes all in columns
#     i.e. key in row and other inner dictionary key  in columns
    
df
# Out:
#                CPN (UML)   Unified Socialist           Independent  \
# Candidate  Sunita Dangol  Rameshwar Shrestha  Benji Singh Maharjan
# Votes              68612               23806                  6555
#
#                       RPP Bibeksheel Sajha
# Candidate  Binita Magaiya   Kirti Kansakar
# Votes               12141             2590

# %%
df = pd.DataFrame.from_dict(data,orient="index") 
df
# Out:
#                               Candidate  Votes
# CPN (UML)                 Sunita Dangol  68612
# Unified Socialist    Rameshwar Shrestha  23806
# Independent        Benji Singh Maharjan   6555
# RPP                      Binita Magaiya  12141
# Bibeksheel Sajha         Kirti Kansakar   2590

# %%
df.reset_index()
# Out:
#                index             Candidate  Votes
# 0          CPN (UML)         Sunita Dangol  68612
# 1  Unified Socialist    Rameshwar Shrestha  23806
# 2        Independent  Benji Singh Maharjan   6555
# 3                RPP        Binita Magaiya  12141
# 4   Bibeksheel Sajha        Kirti Kansakar   2590

# %% [markdown]
# ### Questions
# 1. *Create a Simple Line Plot:*
#    - Generate a series of 50 points using `np.linspace` for x-values between 0 and 10.
#    - Create y-values as the sine of x-values.
#    - Plot these points using a line plot.

# %%
import numpy as np

# %%
x=np.linspace(0,10,50)

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
y=np.sin(x)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# 2. *Generate a Basic Bar Chart:*
#    - Create a bar chart with the following categories and values: 'Red' (10), 'Blue' (15), 'Green' (7).
#    - Label each axis appropriately.

# %%
data={"color":["Red","Blue","Green"],"val":[10,15,7]}

# %%
categories=data["color"]
categories
# Out:
# ['Red', 'Blue', 'Green']

# %%
values=data["val"]
print(values)
# Out:
# [10, 15, 7]

# %%
plt.bar(categories,values,color=["Red","blue","green"])
plt.title("Bar Plot of Values by Color")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.xticks(fontsize=11)  # Sets the font size of xtick labels to 12
plt.xticks([0, 1, 2], ['A', 'B', 'C']) # set the locations and labels of xticks

plt.show()
