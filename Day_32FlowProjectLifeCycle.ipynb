# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# data transformation= normalization kind of thing
# sometimes data may have both english nepali date with time that must be cleaned or transformed.
